# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuelcb08/TRABAJO_FINAL_PARTE2/blob/main/Trabajo_final_parte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos_transporte = pd.read_csv("/content/drive/MyDrive/Info_Vehiculos.csv", sep = ",")

# %%
datos_transporte
# Out:
#      Unnamed: 0    id             Nombre    Apellido  \
# 0             0     5      Hilda Demeter     Demeter
# 1             1     6  Morton Dalliwater  Dalliwater
# 2             2     8         Darrin Rew         Rew
# 3             3     9  Rossie Pitceathly  Pitceathly
# 4             4    17     Webster Wenman      Wenman
# ..          ...   ...                ...         ...
# 231         231   983      Jilleen Delle       Delle
# 232         232   985      Martino Rayer       Rayer
# 233         233   993     Duke Wickstead   Wickstead
# 234         234   995     Fanni Bartosik    Bartosik
# 235         235  1000       Raul Belison     Belison
#
#                              email      Genero       Marca       Color
# 0                hdemeter4@nba.com      Female        Ford      Orange
# 1       mdalliwater5@indiegogo.com        Male  Volkswagen      Violet
# 2                   drew7@yale.edu  Polygender     Ferrari  Aquamarine
# ...

# %%
datos_transporte.head(30)
# Out:
#     Unnamed: 0   id              Nombre    Apellido  \
# 0            0    5       Hilda Demeter     Demeter
# 1            1    6   Morton Dalliwater  Dalliwater
# 2            2    8          Darrin Rew         Rew
# 3            3    9   Rossie Pitceathly  Pitceathly
# 4            4   17      Webster Wenman      Wenman
# 5            5   18  Marguerite Capener     Capener
# 6            6   22  Alanson Spencelayh  Spencelayh
# 7            7   32        Deva Aldhous     Aldhous
# 8            8   35       Tresa Pilgram     Pilgram
# 9            9   37   Novelia Babington   Babington
# 10          10   43       Jeanna Grooby      Grooby
# 11          11   50   Davidde Pitbladdo   Pitbladdo
# 12          12   54    Brandea Gwinnell    Gwinnell
# 13          13   59     Nobie Wellesley   Wellesley
# 14          14   67      Lurleen Machan      Machan
# 15          15   75      Clarance Ferre       Ferre
# 16          16   77      Bone Sommerlie   Sommerlie
# ...

# %%
sel_Vehiculos = datos_transporte["Marca"]== "Ford"
cant_Vehiculos_otras = datos_transporte[~sel_Vehiculos].shape[0]
cant_Vehiculos_otras
# Out:
# 139

# %%
sel_personas =datos_transporte["Genero"]== "Male"
cant_personas = datos_transporte[~sel_personas].shape[0]
cant_personas
# Out:
# 119

# %%
sel_carros = datos_transporte["Color"]=="Green"
cant_carros = datos_transporte[~sel_carros].shape[0]
cant_carros
# Out:
# 223

# %%
print("Se encontro la siguiente info")
print(f"El numero de carros ford son {cant_Vehiculos_otras}")
print(f"El numero de carros rojos son {cant_carros}")
print(f"El numero de personas Male es {cant_personas}")
# Out:
# Se encontro la siguiente info
# El numero de carros ford son 139
# El numero de carros rojos son 223
# El numero de personas Male es 119

# %%
datos_transporte.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0    id             Nombre    Apellido  \
# 0             0     5      Hilda Demeter     Demeter
# 1             1     6  Morton Dalliwater  Dalliwater
# 2             2     8         Darrin Rew         Rew
# 3             3     9  Rossie Pitceathly  Pitceathly
# 4             4    17     Webster Wenman      Wenman
# ..          ...   ...                ...         ...
# 231         231   983      Jilleen Delle       Delle
# 232         232   985      Martino Rayer       Rayer
# 233         233   993     Duke Wickstead   Wickstead
# 234         234   995     Fanni Bartosik    Bartosik
# 235         235  1000       Raul Belison     Belison
#
#                              email      Genero       Marca       Color
# 0                hdemeter4@nba.com      Female        Ford      Orange
# 1       mdalliwater5@indiegogo.com        Male  Volkswagen      Violet
# 2                   drew7@yale.edu  Polygender     Ferrari  Aquamarine
# ...
